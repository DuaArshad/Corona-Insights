# %% [markdown]
# # Data Cleaning

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Reading Data "TimeSeries_KeyIndicators"

# %%
df = pd.read_excel(r"F:\\university\\Semester6\\COVID_FINAL_DATA.xlsx", "TimeSeries_KeyIndicators")

# %%
df.head()
# Out:
#    Unnamed: 0  Cumulative  Cumulative  Test positive  \
# 0           4          48                          2
# 1           5          61                          0
# 2           6          84                         14
# 3           7          20                          0
# 4           8           3                          0
#
#    Cumulative  tests performed                 Date  Discharged  Expired  \
# 0                           80  2020-03-11 00:00:00           0        0
# 1                           95  2020-03-11 00:00:00           0        0
# 2                          171  2020-03-11 00:00:00           1        0
# 3                           28  2020-03-11 00:00:00           0        0
# 4                            0  2020-03-11 00:00:00           0        0
#
#    Home Quarantine  New  (last 24 hrs)  Region  Still admitted  \
# 0              NaN                   3     ICT               2
# 1              NaN                   6  Punjab               0
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0                             int64
# Cumulative                             int64
# Cumulative  Test positive              int64
# Cumulative  tests performed            int64
# Date                                  object
# Discharged                             int64
# Expired                                int64
# Home Quarantine                      float64
# New  (last 24 hrs)                     int64
# Region                                object
# Still admitted                         int64
# Tests  performed in last 24 hours     object
# dtype: object

# %%
df=df.replace('GB', 'Gilgit Baltistan')
df=df.replace('AJK', 'Azad Jamu & Kashmir')
df=df.replace('ICT', 'Islamabad Capital Teritorry')
df=df.replace('KP', 'Khyber PakhtunKhua')

# %%
df.isnull()
# Out:
#      Unnamed: 0  Cumulative  Cumulative  Test positive  \
# 0         False       False                      False
# 1         False       False                      False
# 2         False       False                      False
# 3         False       False                      False
# 4         False       False                      False
# ..          ...         ...                        ...
# 435       False       False                      False
# 436       False       False                      False
# 437       False       False                      False
# 438       False       False                      False
# 439       False       False                      False
#
#      Cumulative  tests performed   Date  Discharged  Expired  Home Quarantine  \
# 0                          False  False       False    False             True
# 1                          False  False       False    False             True
# ...

# %%
df = df.rename(columns = {"Unnamed: 0":"F1"})
df.head()
# Out:
#    F1  Cumulative  Cumulative  Test positive  Cumulative  tests performed  \
# 0   4          48                          2                           80
# 1   5          61                          0                           95
# 2   6          84                         14                          171
# 3   7          20                          0                           28
# 4   8           3                          0                            0
#
#                   Date  Discharged  Expired  Home Quarantine  \
# 0  2020-03-11 00:00:00           0        0              NaN
# 1  2020-03-11 00:00:00           0        0              NaN
# 2  2020-03-11 00:00:00           1        0              NaN
# 3  2020-03-11 00:00:00           0        0              NaN
# 4  2020-03-11 00:00:00           0        0              NaN
#
#    New  (last 24 hrs)                       Region  Still admitted  \
# 0                   3  Islamabad Capital Teritorry               2
# ...

# %%
df.isnull().any()
# Out:
# F1                                   False
# Cumulative                           False
# Cumulative  Test positive            False
# Cumulative  tests performed          False
# Date                                 False
# Discharged                           False
# Expired                              False
# Home Quarantine                       True
# New  (last 24 hrs)                   False
# Region                               False
# Still admitted                       False
# Tests  performed in last 24 hours    False
# dtype: bool

# %%
df["Home Quarantine"].fillna(0, inplace = True)
df.isnull().any()
# Out:
# F1                                   False
# Cumulative                           False
# Cumulative  Test positive            False
# Cumulative  tests performed          False
# Date                                 False
# Discharged                           False
# Expired                              False
# Home Quarantine                      False
# New  (last 24 hrs)                   False
# Region                               False
# Still admitted                       False
# Tests  performed in last 24 hours    False
# dtype: bool

# %%
df.head()
# Out:
#    F1  Cumulative  Cumulative  Test positive  Cumulative  tests performed  \
# 0   4          48                          2                           80
# 1   5          61                          0                           95
# 2   6          84                         14                          171
# 3   7          20                          0                           28
# 4   8           3                          0                            0
#
#                   Date  Discharged  Expired  Home Quarantine  \
# 0  2020-03-11 00:00:00           0        0              0.0
# 1  2020-03-11 00:00:00           0        0              0.0
# 2  2020-03-11 00:00:00           1        0              0.0
# 3  2020-03-11 00:00:00           0        0              0.0
# 4  2020-03-11 00:00:00           0        0              0.0
#
#    New  (last 24 hrs)                       Region  Still admitted  \
# 0                   3  Islamabad Capital Teritorry               2
# ...

# %%
df.to_excel("F:\\university\\TimeSeries_KeyIndicators.xlsx")

# %% [markdown]
# # Reading Data: "TimeSeries_Action_Screen"

# %%
df = pd.read_excel(r"F:\university\Semester6\COVID_FINAL_DATA.xlsx", "TimeSeries_Action_Screen")

# %%
df.head()
# Out:
#           Date  Cumulative travelers Screened  Suspected at Points of Entry  \
# 0  11-Mar-2020                         873288                            26
# 1  12-Mar-2020                         894256                            29
# 2  13-Mar-2020                         913542                            33
# 3  14-Mar-2020                         933970                            43
# 4  15-Mar-2020                         954646                            59
#
#    Travelers Screened at Points ofEntry in last 24 hours
# 0                                              21102
# 1                                              20968
# 2                                              19286
# 3                                              20428
# 4                                              20676

# %%
df.dtypes
# Out:
# Date                                                     object
# Cumulative travelers Screened                             int64
# Suspected at Points of Entry                              int64
# Travelers Screened at Points ofEntry in last 24 hours     int64
# dtype: object

# %%
df = df.rename(columns = {"Travelers Screened at Points ofEntry in last 24 hours":"Travelers Screened at Points of Entry in last 24 hours"})

# %%
df.head()
# Out:
#           Date  Cumulative travelers Screened  Suspected at Points of Entry  \
# 0  11-Mar-2020                         873288                            26
# 1  12-Mar-2020                         894256                            29
# 2  13-Mar-2020                         913542                            33
# 3  14-Mar-2020                         933970                            43
# 4  15-Mar-2020                         954646                            59
#
#    Travelers Screened at Points of Entry in last 24 hours
# 0                                              21102
# 1                                              20968
# 2                                              19286
# 3                                              20428
# 4                                              20676

# %%
df.isnull().any()
# Out:
# Date                                                      False
# Cumulative travelers Screened                             False
# Suspected at Points of Entry                              False
# Travelers Screened at Points of Entry in last 24 hours    False
# dtype: bool

# %%
df.to_excel("F:\\university\\TimeSeries_Action_Screen.xlsx")

# %% [markdown]
# # Reading Data: "TimeSeries_Action_Call

# %%
df = pd.read_excel(r"F:\university\Semester6\COVID_FINAL_DATA.xlsx", "TimeSeries_Action_Call")

# %%
df.head()
# Out:
#               Returnees  Advised Self-Quarantine  \
# 0   Returnees from Iran                        0
# 1  Returnees from China                       11
# 2   Returnees from Iran                       14
# 3  Returnees from China                        7
# 4   Returnees from Iran                        0
#
#    Cumulative no offirst-time calls  Cumulativefollow-up calls         Date  \
# 0                              9459                       2553  11-Mar-2020
# 1                              5342                       7746  11-Mar-2020
# 2                              9475                       3221  12-Mar-2020
# 3                              5352                       7855  12-Mar-2020
# 4                              9475                       3853  13-Mar-2020
#
#    First-time calls inpast 24 hrs  Follow-up calls inpast 24 hrs
# 0                               0                            353
# 1                              17                            400
# ...

# %%
df.dtypes
# Out:
# Returnees                           object
# Advised Self-Quarantine              int64
# Cumulative no offirst-time calls     int64
# Cumulativefollow-up calls            int64
# Date                                object
# First-time calls inpast 24 hrs       int64
# Follow-up calls inpast 24 hrs        int64
# dtype: object

# %%
df.isnull().any()
# Out:
# Returnees                           False
# Advised Self-Quarantine             False
# Cumulative no offirst-time calls    False
# Cumulativefollow-up calls           False
# Date                                False
# First-time calls inpast 24 hrs      False
# Follow-up calls inpast 24 hrs       False
# dtype: bool

# %%
df.to_excel("F:\\university\\TimeSeries_Action_Call.xlsx")

# %% [markdown]
# # Reading Data: "TimeSeries_COVID_News"

# %%
df = pd.read_excel(r"F:\university\Semester6\COVID_FINAL_DATA.xlsx", "TimeSeries_COVID_News")

# %%
df.head()
# Out:
#    Unnamed: 0         Date                                               News  \
# 0           0  11-Mar-2020                                 Updates: Pakistan:
# 1           1  11-Mar-2020  Three new cases have been confirmed in the pas...
# 2           2  11-Mar-2020  Number of calls to passengers returning from I...
# 3           3  11-Mar-2020                                            Global:
# 4           4  11-Mar-2020       Total cases: 118,887,  Total Deaths: 4,290 •
#
#                                             Agg News
# 0  Updates: Pakistan: \n Three new cases have bee...
# 1  Updates: Pakistan: \n Three new cases have bee...
# 2  Updates: Pakistan: \n Three new cases have bee...
# 3  Updates: Pakistan: \n Three new cases have bee...
# 4  Updates: Pakistan: \n Three new cases have bee...

# %%
df["Agg News"][0]
# Out:
# 'Updates: Pakistan: \n Three new cases have been confirmed in the past 24 hours, bringing the tally to 19. • \n Number of calls to passengers returning from Iraq: 144 • \n Global: \n Total cases: 118,887,  Total Deaths: 4,290 • \n Total affected countries: 109 including Turkey and Panama. •'

# %%
df=df.rename(columns = {"Agg News":"News Details"})
df.head()
# Out:
#    Unnamed: 0         Date                                               News  \
# 0           0  11-Mar-2020                                 Updates: Pakistan:
# 1           1  11-Mar-2020  Three new cases have been confirmed in the pas...
# 2           2  11-Mar-2020  Number of calls to passengers returning from I...
# 3           3  11-Mar-2020                                            Global:
# 4           4  11-Mar-2020       Total cases: 118,887,  Total Deaths: 4,290 •
#
#                                         News Details
# 0  Updates: Pakistan: \n Three new cases have bee...
# 1  Updates: Pakistan: \n Three new cases have bee...
# 2  Updates: Pakistan: \n Three new cases have bee...
# 3  Updates: Pakistan: \n Three new cases have bee...
# 4  Updates: Pakistan: \n Three new cases have bee...

# %%
del df["Unnamed: 0"]
df.head()
# Out:
#           Date                                               News  \
# 0  11-Mar-2020                                 Updates: Pakistan:
# 1  11-Mar-2020  Three new cases have been confirmed in the pas...
# 2  11-Mar-2020  Number of calls to passengers returning from I...
# 3  11-Mar-2020                                            Global:
# 4  11-Mar-2020       Total cases: 118,887,  Total Deaths: 4,290 •
#
#                                         News Details
# 0  Updates: Pakistan: \n Three new cases have bee...
# 1  Updates: Pakistan: \n Three new cases have bee...
# 2  Updates: Pakistan: \n Three new cases have bee...
# 3  Updates: Pakistan: \n Three new cases have bee...
# 4  Updates: Pakistan: \n Three new cases have bee...

# %%
df.dtypes
# Out:
# Date            object
# News            object
# News Details    object
# dtype: object

# %%
df.isnull().any()
# Out:
# Date            False
# News            False
# News Details    False
# dtype: bool

# %%
df.to_excel("F:\\university\\TimeSeries_COVID_News.xlsx")

# %% [markdown]
# # Reading Data: "TimeSeries_NIH_Response"

# %%
df = pd.read_excel(r"F:\university\Semester6\COVID_FINAL_DATA.xlsx", "TimeSeries_NIH_Response")

# %%
df.head()
# Out:
#    Unnamed: 0         Date                      NIH Preparedness and Response  \
# 0           0  11-Mar-2020  BSL-3 mobile lab with state of art equipment h...
# 1           1  11-Mar-2020  IPC trainings have been completed at Gilgit an...
# 2           2  11-Mar-2020  Training of the GB lab staff has been conducte...
# 3           3  11-Mar-2020  IPC training is in progress for FG Hospital st...
# 4           0  12-Mar-2020          BSL-3 mobile lab is ready for testing.  •
#
#                    Agg NIH Preparedness and Response
# 0  BSL-3 mobile lab with state of art equipment h...
# 1  BSL-3 mobile lab with state of art equipment h...
# 2  BSL-3 mobile lab with state of art equipment h...
# 3  BSL-3 mobile lab with state of art equipment h...
# 4  BSL-3 mobile lab is ready for testing.  • \n I...

# %%
del df["Unnamed: 0"]
df.head()
# Out:
#           Date                      NIH Preparedness and Response  \
# 0  11-Mar-2020  BSL-3 mobile lab with state of art equipment h...
# 1  11-Mar-2020  IPC trainings have been completed at Gilgit an...
# 2  11-Mar-2020  Training of the GB lab staff has been conducte...
# 3  11-Mar-2020  IPC training is in progress for FG Hospital st...
# 4  12-Mar-2020          BSL-3 mobile lab is ready for testing.  •
#
#                    Agg NIH Preparedness and Response
# 0  BSL-3 mobile lab with state of art equipment h...
# 1  BSL-3 mobile lab with state of art equipment h...
# 2  BSL-3 mobile lab with state of art equipment h...
# 3  BSL-3 mobile lab with state of art equipment h...
# 4  BSL-3 mobile lab is ready for testing.  • \n I...

# %%
df=df.rename(columns = {"Agg NIH Preparedness and Response":"Detail of NIH Preparedness and Response"})
df.head()
# Out:
#           Date                      NIH Preparedness and Response  \
# 0  11-Mar-2020  BSL-3 mobile lab with state of art equipment h...
# 1  11-Mar-2020  IPC trainings have been completed at Gilgit an...
# 2  11-Mar-2020  Training of the GB lab staff has been conducte...
# 3  11-Mar-2020  IPC training is in progress for FG Hospital st...
# 4  12-Mar-2020          BSL-3 mobile lab is ready for testing.  •
#
#              Detail of NIH Preparedness and Response
# 0  BSL-3 mobile lab with state of art equipment h...
# 1  BSL-3 mobile lab with state of art equipment h...
# 2  BSL-3 mobile lab with state of art equipment h...
# 3  BSL-3 mobile lab with state of art equipment h...
# 4  BSL-3 mobile lab is ready for testing.  • \n I...

# %%
df.dtypes
# Out:
# Date                                       object
# NIH Preparedness and Response              object
# Detail of NIH Preparedness and Response    object
# dtype: object

# %%
df.isnull().any()
# Out:
# Date                                       False
# NIH Preparedness and Response              False
# Detail of NIH Preparedness and Response    False
# dtype: bool

# %%
df
# Out:
#                    Date                      NIH Preparedness and Response  \
# 0           11-Mar-2020  BSL-3 mobile lab with state of art equipment h...
# 1           11-Mar-2020  IPC trainings have been completed at Gilgit an...
# 2           11-Mar-2020  Training of the GB lab staff has been conducte...
# 3           11-Mar-2020  IPC training is in progress for FG Hospital st...
# 4           12-Mar-2020          BSL-3 mobile lab is ready for testing.  •
# ..                  ...                                                ...
# 60  2020-04-02 00:00:00  Risk communication carried out among healthcar...
# 61  2020-04-02 00:00:00  NIH laboratory is providing support to provinc...
# 62  2020-04-03 00:00:00  Contact tracing of confirmed cases being carri...
# 63  2020-04-03 00:00:00  Risk communication carried out among healthcar...
# 64  2020-04-03 00:00:00  NIH laboratory is providing support to provinc...
#
#               Detail of NIH Preparedness and Response
# ...

# %%
df=df.astype(str)

# %%
df["Date"][55]
# Out:
# '2020-03-31 00:00:00'

# %%
df=df.replace('2020-03-31 00:00:00', '31-March-2020')
df=df.replace('2020-04-01 00:00:00', '01-Apr-2020')
df=df.replace('2020-04-02 00:00:00', '02-Apr-2020')
df=df.replace('2020-04-03 00:00:00', '03-Apr-2020')

# %%
df
# Out:
#            Date                      NIH Preparedness and Response  \
# 0   11-Mar-2020  BSL-3 mobile lab with state of art equipment h...
# 1   11-Mar-2020  IPC trainings have been completed at Gilgit an...
# 2   11-Mar-2020  Training of the GB lab staff has been conducte...
# 3   11-Mar-2020  IPC training is in progress for FG Hospital st...
# 4   12-Mar-2020          BSL-3 mobile lab is ready for testing.  •
# ..          ...                                                ...
# 60  02-Apr-2020  Risk communication carried out among healthcar...
# 61  02-Apr-2020  NIH laboratory is providing support to provinc...
# 62  03-Apr-2020  Contact tracing of confirmed cases being carri...
# 63  03-Apr-2020  Risk communication carried out among healthcar...
# 64  03-Apr-2020  NIH laboratory is providing support to provinc...
#
#               Detail of NIH Preparedness and Response
# 0   BSL-3 mobile lab with state of art equipment h...
# ...

# %%
df.to_excel("F:\\university\\TimeSeries_NIH_Response.xlsx")

# %% [markdown]
# # Reading Data: "TimeSeries_Province_Response"

# %%
df = pd.read_excel(r"F:\university\Semester6\COVID_FINAL_DATA.xlsx", "TimeSeries_Province_Response")

# %%
df.head()
# Out:
#    Unnamed: 0       region                Provinces Preparedness and Response  \
# 0           0  Balochistan  316 newly arrived individuals screened and qua...
# 1           1  Balochistan  14 Chinese nationals quarantined at East Bay E...
# 2           2        Sindh  Staff deployed to designated quarantine facili...
# 3           3        Sindh  Training and orientation sessions for the heal...
# 4           4      KP & TD  24 High Dependency Units established across KP...
#
#           Date            Agg Provinces Preparedness and Response
# 0  11-Mar-2020  316 newly arrived individuals screened and qua...
# 1  11-Mar-2020  316 newly arrived individuals screened and qua...
# 2  11-Mar-2020  Staff deployed to designated quarantine facili...
# 3  11-Mar-2020  Staff deployed to designated quarantine facili...
# 4  11-Mar-2020  24 High Dependency Units established across KP...

# %%
del df["Unnamed: 0"]

# %%
df.head()
# Out:
#         region                Provinces Preparedness and Response  \
# 0  Balochistan  316 newly arrived individuals screened and qua...
# 1  Balochistan  14 Chinese nationals quarantined at East Bay E...
# 2        Sindh  Staff deployed to designated quarantine facili...
# 3        Sindh  Training and orientation sessions for the heal...
# 4      KP & TD  24 High Dependency Units established across KP...
#
#           Date            Agg Provinces Preparedness and Response
# 0  11-Mar-2020  316 newly arrived individuals screened and qua...
# 1  11-Mar-2020  316 newly arrived individuals screened and qua...
# 2  11-Mar-2020  Staff deployed to designated quarantine facili...
# 3  11-Mar-2020  Staff deployed to designated quarantine facili...
# 4  11-Mar-2020  24 High Dependency Units established across KP...

# %%
df=df.rename(columns={"region":"Region"})
df.head()
# Out:
#         Region                Provinces Preparedness and Response  \
# 0  Balochistan  316 newly arrived individuals screened and qua...
# 1  Balochistan  14 Chinese nationals quarantined at East Bay E...
# 2        Sindh  Staff deployed to designated quarantine facili...
# 3        Sindh  Training and orientation sessions for the heal...
# 4      KP & TD  24 High Dependency Units established across KP...
#
#           Date            Agg Provinces Preparedness and Response
# 0  11-Mar-2020  316 newly arrived individuals screened and qua...
# 1  11-Mar-2020  316 newly arrived individuals screened and qua...
# 2  11-Mar-2020  Staff deployed to designated quarantine facili...
# 3  11-Mar-2020  Staff deployed to designated quarantine facili...
# 4  11-Mar-2020  24 High Dependency Units established across KP...

# %%
df=df.astype(str)

# %%
df=df.replace('2020-03-31 00:00:00', '31-March-2020')
df=df.replace('2020-04-01 00:00:00', '01-Apr-2020')
df=df.replace('2020-04-02 00:00:00', '02-Apr-2020')
df=df.replace('2020-04-03 00:00:00', '03-Apr-2020')

# %%
df
# Out:
#           Region                Provinces Preparedness and Response  \
# 0    Balochistan  316 newly arrived individuals screened and qua...
# 1    Balochistan  14 Chinese nationals quarantined at East Bay E...
# 2          Sindh  Staff deployed to designated quarantine facili...
# 3          Sindh  Training and orientation sessions for the heal...
# 4        KP & TD  24 High Dependency Units established across KP...
# ..           ...                                                ...
# 161        Sindh  Sindh Government has disbursed Rs.569.604 mill...
# 162       Punjab  District level trainings of HDU/Isolation/Quar...
# 163           KP  Data transcription on to the IPMS software hos...
# 164          AJK  Out of 9 confirmed cases, 6 are local transmis...
# 165           GB  Involvement of WHO staff to provide support in...
#
#             Date            Agg Provinces Preparedness and Response
# 0    11-Mar-2020  316 newly arrived individuals screened and qua...
# ...

# %%
df=df.replace('GB', 'Gilgit Baltistan')
df=df.replace('AJK', 'Azad Jamu & Kashmir')
df=df.replace('ICT', 'Islamabad Capital Teritorry')
df=df.replace('KP', 'Khyber PakhtunKhua')

# %%
df
# Out:
#                   Region                Provinces Preparedness and Response  \
# 0            Balochistan  316 newly arrived individuals screened and qua...
# 1            Balochistan  14 Chinese nationals quarantined at East Bay E...
# 2                  Sindh  Staff deployed to designated quarantine facili...
# 3                  Sindh  Training and orientation sessions for the heal...
# 4                KP & TD  24 High Dependency Units established across KP...
# ..                   ...                                                ...
# 161                Sindh  Sindh Government has disbursed Rs.569.604 mill...
# 162               Punjab  District level trainings of HDU/Isolation/Quar...
# 163   Khyber PakhtunKhua  Data transcription on to the IPMS software hos...
# 164  Azad Jamu & Kashmir  Out of 9 confirmed cases, 6 are local transmis...
# 165     Gilgit Baltistan  Involvement of WHO staff to provide support in...
#
# ...

# %%
df.to_excel("F:\\university\\TimeSeries_Province_Response.xlsx")

# %% [markdown]
# # Reading Data: "TimeSeries_Helpline_Calls"

# %%
df = pd.read_excel(r"F:\university\Semester6\COVID_FINAL_DATA.xlsx", "TimeSeries_Helpline_Calls")

# %%
df
# Out:
#     Unnamed: 0  Cumulative Calls       Date  New Calls
# 0            0             12481 2020-03-11        547
# 1            0             13167 2020-03-12        686
# 2            0             13896 2020-03-13        729
# 3            0             15340 2020-03-14       1444
# 4            0             19131 2020-03-15       3791
# 5            0             26193 2020-03-16       7062
# 6            0             33427 2020-03-17       7234
# 7            0             41563 2020-03-18       8136
# 8            0             48786 2020-03-19       7223
# 9            0             56892 2020-03-20       8106
# 10           0             65602 2020-03-21       8710
# 11           0             65602 2020-03-22       8710
# 12           0             84700 2020-03-23       9654
# 13           0             93991 2020-03-24       9291
# 14           0            110052 2020-03-25      16061
# 15           0            152633 2020-03-26      42581
# ...

# %%
del df["Unnamed: 0"]

# %%
df.head()
# Out:
#    Cumulative Calls       Date  New Calls
# 0             12481 2020-03-11        547
# 1             13167 2020-03-12        686
# 2             13896 2020-03-13        729
# 3             15340 2020-03-14       1444
# 4             19131 2020-03-15       3791

# %%
df.dtypes
# Out:
# Cumulative Calls             int64
# Date                datetime64[ns]
# New Calls                    int64
# dtype: object

# %%
df=df.astype({"Date":str})
df.isnull().any()
# Out:
# Cumulative Calls    False
# Date                False
# New Calls           False
# dtype: bool

# %%
df.dtypes
# Out:
# Cumulative Calls     int64
# Date                object
# New Calls            int64
# dtype: object

# %%
df.to_excel("F:\\university\\TimeSeries_Helpline_Calls.xlsx")

# %% [markdown]
# # Reading Data: "TimeSeries_Quarantine_Details"

# %%
df = pd.read_excel(r"F:\university\Semester6\COVID_FINAL_DATA.xlsx", "TimeSeries_Quarantine_Details")

# %%
df.head()
# Out:
#    Unnamed: 0      Regions  Quarantine facilities (n)  \
# 0           0          ICT                          1
# 1           1       Punjab                          4
# 2           2        Sindh                          5
# 3           3           KP                         92
# 4           4  Balochistan                          9
#
#    No. of arrivals in last 24 hrs  Cumulative no of persons present       Date
# 0                               0                                24 2020-04-01
# 1                               0                              2956 2020-04-01
# 2                               0                              1388 2020-04-01
# 3                             181                              3260 2020-04-01
# 4                               0                               366 2020-04-01

# %%
del df["Unnamed: 0"]

# %%
df=df.rename(columns={"Regions":"Region"})

# %%
df=df.replace('GB', 'Gilgit Baltistan')
df=df.replace('AJK', 'Azad Jamu & Kashmir')
df=df.replace('ICT', 'Islamabad Capital Teritorry')
df=df.replace('KP', 'Khyber PakhtunKhua')

# %%
df
# Out:
#                          Region  Quarantine facilities (n)  \
# 0   Islamabad Capital Teritorry                          1
# 1                        Punjab                          4
# 2                         Sindh                          5
# 3            Khyber PakhtunKhua                         92
# 4                   Balochistan                          9
# 5           Azad Jamu & Kashmir                         13
# 6              Gilgit Baltistan                         47
# 7   Islamabad Capital Teritorry                          1
# 8                        Punjab                          4
# 9                         Sindh                          5
# 10           Khyber PakhtunKhua                         98
# 11                  Balochistan                          9
# 12          Azad Jamu & Kashmir                         37
# 13             Gilgit Baltistan                         47
# 14  Islamabad Capital Teritorry                          6
# ...

# %%
df.dtypes
# Out:
# Region                                      object
# Quarantine facilities (n)                    int64
# No. of arrivals in last 24 hrs               int64
# Cumulative no of persons present             int64
# Date                                datetime64[ns]
# dtype: object

# %%
df=df.astype({"Date":str})
df.isnull().any()
# Out:
# Region                              False
# Quarantine facilities (n)           False
# No. of arrivals in last 24 hrs      False
# Cumulative no of persons present    False
# Date                                False
# dtype: bool

# %%
df.dtypes
# Out:
# Region                              object
# Quarantine facilities (n)            int64
# No. of arrivals in last 24 hrs       int64
# Cumulative no of persons present     int64
# Date                                object
# dtype: object

# %%
df.to_excel("F:\\university\\TimeSeries_Quarantine_Details.xlsx")

# %% [markdown]
# # Reading Data: "TimeSeries_KeyIndicators_Detail"

# %%
df = pd.read_excel(r"F:\university\Semester6\COVID_FINAL_DATA.xlsx", "TimeSeries_KeyIndicators_Detail")

# %%
df.head()
# Out:
#         Date Province Old  Suspected Cases Last Date  \
# 0 2020-04-04          AJK                        322
# 1 2020-04-04  Balochistan                       2171
# 2 2020-04-04           GB                        961
# 3 2020-04-04          ICT                       2395
# 4 2020-04-04           KP                       1938
#
#    Suspected Cases Last 24 Hrs  Suspected Cases Cumulative  \
# 0                           21                         343
# 1                          230                        2401
# 2                            2                         963
# 3                          174                        2569
# 4                          431                        2369
#
#    Lab Tests Last 24 Hrs  Lab Tests Cumulative  Confirmed Cases Last Date  \
# 0                     21                   343                          9
# 1                      0                  2401                        169
# ...

# %%
df.isnull().any()
# Out:
# Date                                         False
# Province Old                                 False
# Suspected Cases Last Date                    False
# Suspected Cases Last 24 Hrs                  False
# Suspected Cases Cumulative                   False
# Lab Tests Last 24 Hrs                        False
# Lab Tests Cumulative                         False
# Confirmed Cases Last Date                    False
# Confirmed Cases Last 24 Hrs                  False
# Confirmed Cases Cumulative                   False
#  Deaths Last Date                            False
#  Deaths Last 24 Hrs                          False
#  Deaths Cumulative                           False
#  Deaths Ventilator Last 24 Hrs               False
# Transmission Total                           False
# Transmission Foreign - Iran                  False
# Transmission Foreign - Iran %                False
# Transmission Foreign - Other                 False
# ...

# %%
df["Unnamed: 53"]
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#       ...
# 219    2.0
# 220    1.0
# 221    2.0
# 222    0.0
# 223    5.0
# Name: Unnamed: 53, Length: 224, dtype: float64

# %%
del df["Unnamed: 53"]
df.head()
# Out:
#         Date Province Old  Suspected Cases Last Date  \
# 0 2020-04-04          AJK                        322
# 1 2020-04-04  Balochistan                       2171
# 2 2020-04-04           GB                        961
# 3 2020-04-04          ICT                       2395
# 4 2020-04-04           KP                       1938
#
#    Suspected Cases Last 24 Hrs  Suspected Cases Cumulative  \
# 0                           21                         343
# 1                          230                        2401
# 2                            2                         963
# 3                          174                        2569
# 4                          431                        2369
#
#    Lab Tests Last 24 Hrs  Lab Tests Cumulative  Confirmed Cases Last Date  \
# 0                     21                   343                          9
# 1                      0                  2401                        169
# ...

# %%
df.isnull().any()
# Out:
# Date                                         False
# Province Old                                 False
# Suspected Cases Last Date                    False
# Suspected Cases Last 24 Hrs                  False
# Suspected Cases Cumulative                   False
# Lab Tests Last 24 Hrs                        False
# Lab Tests Cumulative                         False
# Confirmed Cases Last Date                    False
# Confirmed Cases Last 24 Hrs                  False
# Confirmed Cases Cumulative                   False
#  Deaths Last Date                            False
#  Deaths Last 24 Hrs                          False
#  Deaths Cumulative                           False
#  Deaths Ventilator Last 24 Hrs               False
# Transmission Total                           False
# Transmission Foreign - Iran                  False
# Transmission Foreign - Iran %                False
# Transmission Foreign - Other                 False
# ...

# %%
df=df.replace('GB', 'Gilgit Baltistan')
df=df.replace('AJK', 'Azad Jamu & Kashmir')
df=df.replace('ICT', 'Islamabad Capital Teritorry')
df=df.replace('KP', 'Khyber PakhtunKhua')

# %%
df.to_excel("F:\\university\\TimeSeries_KeyIndicators_Detail.xlsx")

# %% [markdown]
# # Reading Data: "TimeSeries_NIH_Risk"

# %%
df = pd.read_excel(r"F:\university\Semester6\COVID_FINAL_DATA.xlsx", "TimeSeries_NIH_Risk")

# %%
df.head()
# Out:
#    Unnamed: 0         Date Risk Assessment NIH
# 0           0  11-Mar-2020           MODERATE.
# 1           0  12-Mar-2020           MODERATE.
# 2           0  13-Mar-2020           MODERATE.
# 3           0  14-Mar-2020           MODERATE.
# 4           0  15-Mar-2020            Moderate

# %%
del df["Unnamed: 0"]

# %%
df.head()
# Out:
#           Date Risk Assessment NIH
# 0  11-Mar-2020           MODERATE.
# 1  12-Mar-2020           MODERATE.
# 2  13-Mar-2020           MODERATE.
# 3  14-Mar-2020           MODERATE.
# 4  15-Mar-2020            Moderate

# %%
df["Risk Assessment NIH"]=df["Risk Assessment NIH"].str.upper()

# %%
df["Risk Assessment NIH"]
# Out:
# 0      MODERATE.
# 1      MODERATE.
# 2      MODERATE.
# 3      MODERATE.
# 4       MODERATE
# 5       MODERATE
# 6       MODERATE
# 7       MODERATE
# 8           HIGH
# 9           HIGH
# 10          HIGH
# 11          HIGH
# 12          HIGH
# 13          HIGH
# 14          HIGH
# 15          HIGH
# 16          HIGH
# 17          HIGH
# 18          HIGH
# 19          HIGH
# 20          HIGH
# 21          HIGH
# 22          HIGH
# 23          HIGH
# Name: Risk Assessment NIH, dtype: object

# %%
df=df.replace(' MODERATE.', 'MODERATE')

# %%
df["Risk Assessment NIH"]
# Out:
# 0      MODERATE
# 1      MODERATE
# 2      MODERATE
# 3      MODERATE
# 4      MODERATE
# 5      MODERATE
# 6      MODERATE
# 7      MODERATE
# 8          HIGH
# 9          HIGH
# 10         HIGH
# 11         HIGH
# 12         HIGH
# 13         HIGH
# 14         HIGH
# 15         HIGH
# 16         HIGH
# 17         HIGH
# 18         HIGH
# 19         HIGH
# 20         HIGH
# 21         HIGH
# 22         HIGH
# 23         HIGH
# Name: Risk Assessment NIH, dtype: object

# %%
df.dtypes
# Out:
# Date                   object
# Risk Assessment NIH    object
# dtype: object

# %%
df.to_excel("F:\\university\\TimeSeries_NIH_Risk.xlsx")
